# %% [markdown]
# IMPORT LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns

# %% [markdown]
# IMPORT FILE CSV

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# # 1 Exploratory Data Analysis

# %% [markdown]
# ## 1.1 Check Null Values

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## 1.2 Check Duplicate Data

# %%
df.shape
# Out:
# (3755, 11)

# %%
df[df.duplicated()]
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 115        2023               SE              FT      Data Scientist  150000
# 123        2023               SE              FT  Analytics Engineer  289800
# 153        2023               MI              FT       Data Engineer  100000
# 154        2023               MI              FT       Data Engineer   70000
# 160        2023               SE              FT       Data Engineer  115000
# ...         ...              ...             ...                 ...     ...
# 3439       2022               MI              FT      Data Scientist   78000
# 3440       2022               SE              FT       Data Engineer  135000
# 3441       2022               SE              FT       Data Engineer  115000
# 3586       2021               MI              FT       Data Engineer  200000
# 3709       2021               MI              FT      Data Scientist   76760
#
# ...

# %%
df[df.duplicated()].shape
# Out:
# (1171, 11)

# %% [markdown]
# ### Copy Data

# %%
df_c = df.copy()

# %%
df_c.shape
# Out:
# (3755, 11)

# %% [markdown]
# ### Delete Duplicate Data

# %%
df_c = df_c.drop_duplicates()

# %%
df_c.shape
# Out:
# (2584, 11)

# %%
df_c[df_c.duplicated()]
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size, job_category, adjusted_salary]
# Index: []

# %%
df_c[df_c.duplicated()].shape
# Out:
# (0, 11)

# %% [markdown]
# ## 1.3 Check Unique Values in Each Column

# %% [markdown]
# ### Check Data Type

# %%
df_c.dtypes
# Out:
# work_year               int64
# experience_level       object
# employment_type        object
# job_title              object
# salary                  int64
# salary_currency        object
# salary_in_usd           int64
# employee_residence     object
# remote_ratio           object
# company_location       object
# company_size           object
# job_category           object
# adjusted_salary       float64
# dtype: object

# %% [markdown]
# ### Check Data stats

# %%
df_c.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  2584.000000  2.584000e+03    2584.000000   2584.000000
# mean   2022.301084  2.103653e+05  133409.280186     50.483746
# std       0.749179  8.080375e+05   67136.837329     48.163707
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  9.000000e+04   84975.000000      0.000000
# 50%    2022.000000  1.346300e+05  130000.000000     50.000000
# 75%    2023.000000  1.825625e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# ### Check Columns

# %%
df_c.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### Unique Values Check

# %%
for column in df_c.columns:
  if df_c[column].dtypes == object:
    num_distinct = df_c[column].nunique()
    distinct_val = df_c[column].unique()
    print(f"{column} : {num_distinct} --> {distinct_val}n")
# Out:
# experience_level : 4 --> ['SE' 'MI' 'EN' 'EX']n
# employment_type : 4 --> ['FT' 'CT' 'FL' 'PT']n
# job_title : 93 --> ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
# ...

# %% [markdown]
# ## 1.4 Rename Value for Better Understanding

# %%
df_c['experience_level'] = df_c['experience_level'].replace({'MI':'Mid/Intermediate Level', 'SE':'Senior', 'EN':'Entry Level', 'EX':'Executive'})

df_c['employment_type'] = df_c['employment_type'].replace({'FT':'Full-Time', 'PT':'Part-Time', 'CT':'Contract', 'FL':'Freelance'})

df_c['remote_ratio'] = df_c['remote_ratio'].replace({0:'On-Site', 50:'Hybird', 100:'Full Remote'})

# %%
df_c.head()
# Out:
#    work_year        experience_level employment_type  \
# 0       2023                  Senior       Full-Time
# 1       2023  Mid/Intermediate Level        Contract
# 2       2023  Mid/Intermediate Level        Contract
# 3       2023                  Senior       Full-Time
# 4       2023                  Senior       Full-Time
#
#                   job_title  salary salary_currency  salary_in_usd  \
# 0  Principal Data Scientist   80000             EUR          85847
# 1               ML Engineer   30000             USD          30000
# 2               ML Engineer   25500             USD          25500
# 3            Data Scientist  175000             USD         175000
# 4            Data Scientist  120000             USD         120000
#
#   employee_residence remote_ratio company_location company_size  \
# 0                 ES  Full Remote               ES            L
# 1                 US  Full Remote               US            S
# ...

# %% [markdown]
# ## 1.5 Group the Job title

# %% [markdown]
# ### Check Job Title

# %%
df_c['job_title'].nunique()
# Out:
# 93

# %%
df_c['job_title'].unique()
# Out:
# array(['Principal Data Scientist', 'ML Engineer', 'Data Scientist',
#        'Applied Scientist', 'Data Analyst', 'Data Modeler',
#        'Research Engineer', 'Analytics Engineer',
#        'Business Intelligence Engineer', 'Machine Learning Engineer',
#        'Data Strategist', 'Data Engineer', 'Computer Vision Engineer',
#        'Data Quality Analyst', 'Compliance Data Analyst',
#        'Data Architect', 'Applied Machine Learning Engineer',
#        'AI Developer', 'Research Scientist', 'Data Analytics Manager',
#        'Business Data Analyst', 'Applied Data Scientist',
#        'Staff Data Analyst', 'ETL Engineer', 'Data DevOps Engineer',
#        'Head of Data', 'Data Science Manager', 'Data Manager',
#        'Machine Learning Researcher', 'Big Data Engineer',
#        'Data Specialist', 'Lead Data Analyst', 'BI Data Engineer',
#        'Director of Data Science', 'Machine Learning Scientist',
#        'MLOps Engineer', 'AI Scientist', 'Autonomous Vehicle Technician',
# ...

# %% [markdown]
# ### Grouping Function

# %%
def assign_broader_category(job_title):
  data_engineering = ["Data Engineer", "Data Analyst", "Analytics Engineer", "BI Data Analyst", "Business Data Analyst", "BI Developer", "BI Analyst", "Business Intelligence Engineer", "BI Data Engineer", "Power BI Developer"]
  data_scientist = ["Data Scientist", "Applied Scientist", "Research Scientist", "3D Computer Vision Researcher", "Deep Learning Researcher", "AI/Computer Vision Engineer", "Product Data Scientist", "Research Scientist", "Applied Data Scientist"]
  machine_learning = ["Machine Learning Engineer", "ML Engineer", "Lead Machine Learning Engineer", "Principal Machine Learning Engineer"]
  data_architecture = ["Data Architect", "Big Data Architect", "Cloud Data Architect", "Principal Data Architect", "Principal Data Analyst", "Principal Machine Learning Engineer"]
  management = ["Data Science Manager", "Director of Data Science", "Head of Data Science", "Data Scientist Lead", "Head of Machine Learning", "Manager Data Management", "Data Analytics Manager", "Machine Learning Manager", "Data Manager", "Data Science Manager", "Lead Machine Learning", "Lead Data Engineer"]

  if job_title in data_engineering:
    return "Data Engineering"
  elif job_title in data_scientist:
    return "Data Scientist"
  elif job_title in machine_learning:
    return "Machine Learning"
  elif job_title in data_architecture:
    return "Data Architecture"
  elif job_title in management:
    return "Management"
  else:
    return "Other"

# %%
df_c['job_category'] = df_c['job_title'].apply(assign_broader_category)

# %%
df_c.head()
# Out:
#    work_year        experience_level employment_type  \
# 0       2023                  Senior       Full-Time
# 1       2023  Mid/Intermediate Level        Contract
# 2       2023  Mid/Intermediate Level        Contract
# 3       2023                  Senior       Full-Time
# 4       2023                  Senior       Full-Time
#
#                   job_title  salary salary_currency  salary_in_usd  \
# 0  Principal Data Scientist   80000             EUR          85847
# 1               ML Engineer   30000             USD          30000
# 2               ML Engineer   25500             USD          25500
# 3            Data Scientist  175000             USD         175000
# 4            Data Scientist  120000             USD         120000
#
#   employee_residence remote_ratio company_location company_size  \
# 0                 ES  Full Remote               ES            L
# 1                 US  Full Remote               US            S
# ...

# %% [markdown]
# ## 1.6 Adjust Salary to Present Values

# %% [markdown]
# ### Inflation Rate

# %%
# Inflation rates
us_inflation_rates = {2019: 0.0181,
                      2020: 0.0123,
                      2021: 0.0470,
                      2022: 0.0800,
                      2023: 0.0410}
global_inflation_rates = {2019: 0.0219,
                          2020: 0.0192,
                          2021: 0.0350,
                          2022: 0.0873,
                          2023: 0.0678}

def adjust_salary(x):
  year = x['work_year']
  ori_salary = x['salary_in_usd']
  currency = x['salary_currency']

  if year == 2023:
    return ori_salary
  else:
    adjust_salary = ori_salary

    for yr in range(year, 2023):
      if currency == 'USD':
        inflation_rates = us_inflation_rates[yr]
      else:
        inflation_rates = global_inflation_rates[yr]
    adjust_salary = adjust_salary * (1 + inflation_rates)
  return adjust_salary

# %%
df_c['adjusted_salary'] = df_c.apply(adjust_salary, axis=1)

# %%
df_c[['work_year','salary_currency','salary_in_usd', 'adjusted_salary']].tail()
# Out:
#       work_year salary_currency  salary_in_usd  adjusted_salary
# 3750       2020             USD         412000      444960.0000
# 3751       2021             USD         151000      163080.0000
# 3752       2020             USD         105000      113400.0000
# 3753       2020             USD         100000      108000.0000
# 3754       2021             INR          94665      102929.2545

# %% [markdown]
# # SOAL No.1
# Show the median adjusted data scientist salary, for each experience level

# %% [markdown]
# ## JAWABAN No.1

# %%
median_salaries = df_c[df_c['job_category'] == 'Data Scientist'].groupby(['job_category','experience_level'])['adjusted_salary'].median()
median_salaries.head()
# Out:
# job_category    experience_level
# Data Scientist  Entry Level                80503.2000
#                 Executive                 171720.0000
#                 Mid/Intermediate Level     95155.7471
#                 Senior                    164580.0000
# Name: adjusted_salary, dtype: float64

# %% [markdown]
# # SOAL No. 2
# Show the number of records for each company_location, sorted descending

# %% [markdown]
# ## JAWABAN No.2

# %%
location_counts = df_c.groupby(['company_location'])['company_location'].count().sort_values(ascending=False)
location_counts
# Out:
# company_location
# US    1929
# GB     155
# CA      83
# IN      57
# DE      55
#       ...
# EG       1
# MT       1
# MK       1
# MD       1
# VN       1
# Name: company_location, Length: 72, dtype: int64

# %% [markdown]
# # SOAL No.3
# From this data, show the median adjusted salary of employee who works for company located in Indonesia, do you think that value represents the salary in Indonesia? why? why not?

# %% [markdown]
# ## JAWABAN No.3

# %%
df_indonesia = df_c[df_c['company_location'] == 'ID'].groupby(['company_location'])['adjusted_salary'].median()

df_indonesia.head()
# Out:
# company_location
# ID    37139.6084
# Name: adjusted_salary, dtype: float64

# %%
df_indonesia = df_c[df_c['company_location'] == 'ID'].groupby(['company_location','salary_currency','experience_level'])['adjusted_salary'].median()

df_indonesia.head()
# Out:
# company_location  salary_currency  experience_level
# ID                INR              Mid/Intermediate Level    58079.2168
#                   USD              Entry Level               16200.0000
# Name: adjusted_salary, dtype: float64

# %%
df_indonesia = df_c[df_c['company_location'] == 'ID'].groupby(['company_location','job_title','experience_level'])['adjusted_salary'].count()

df_indonesia.head()
# Out:
# company_location  job_title       experience_level
# ID                Data Analyst    Entry Level               1
#                   Data Scientist  Mid/Intermediate Level    1
# Name: adjusted_salary, dtype: int64

# %% [markdown]
# **Kesimpulan** <br>
#
# 575287994,90 untuk angka segitu dalam Rupiah terlalu banyak untuk rata-rata gaji pegawai di Indonesia.
#
# Menurut https://id.jobstreet.com/id/career-advice/role/officer/salary , gaji rata-rata orang Indonesia berkisar Rp 5.500.000 hingga Rp 7.280.000.
